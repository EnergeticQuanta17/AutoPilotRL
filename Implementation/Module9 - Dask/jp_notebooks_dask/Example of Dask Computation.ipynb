# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# C:\Users\mpree\anaconda3\lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 60014 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:60015' processes=4 threads=8, memory=7.79 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)

# %%
# !pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2023.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\mpree\anaconda3\lib\site-packages (from s3fs) (3.8.1)
# Collecting aiobotocore~=2.5.0
#   Downloading aiobotocore-2.5.0-py3-none-any.whl (72 kB)
# Collecting fsspec==2023.4.0
#   Downloading fsspec-2023.4.0-py3-none-any.whl (153 kB)
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.29.77,>=1.29.76
#   Downloading botocore-1.29.76-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: wrapt>=1.10.10 in c:\users\mpree\anaconda3\lib\site-packages (from aiobotocore~=2.5.0->s3fs) (1.12.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mpree\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\mpree\anaconda3\lib\site-packages (from aioitertools>=0.5.1->aiobotocore~=2.5.0->s3fs) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\mpree\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.26.13)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\mpree\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mpree\anaconda3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mpree\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\mpree\appdata\roaming\python\python39\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.10)
# Installing collected packages: botocore, aioitertools, fsspec, aiobotocore, s3fs
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.24.32
#     Uninstalling botocore-1.24.32:
#       Successfully uninstalled botocore-1.24.32
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.2.0
#     Uninstalling fsspec-2022.2.0:
#       Successfully uninstalled fsspec-2022.2.0
# Successfully installed aiobotocore-2.5.0 aioitertools-0.11.0 botocore-1.29.76 fsspec-2023.4.0 s3fs-2023.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.21.32 requires botocore<1.25.0,>=1.24.32, but you have botocore 1.29.76 which is incompatible.

# %%
ddf.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ddf.head()
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\core.py:1389, in _Frame.head(self, n, npartitions, compute)
#    1387 # No need to warn if we're already looking at all partitions
#    1388 safe = npartitions != self.npartitions
# -> 1389 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\core.py:1423, in _Frame._head(self, n, npartitions, compute, safe)
#    1418 result = new_dd_object(
#    1419     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1420 )
#    1422 if compute:
# -> 1423     result = result.compute()
#    1424 return result
#
# File ~\anaconda3\lib\site-packages\dask\base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File ~\anaconda3\lib\site-packages\dask\base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\anaconda3\lib\site-packages\distributed\client.py:3186, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3184         should_rejoin = False
#    3185 try:
# -> 3186     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3187 finally:
#    3188     for f in futures.values():
#
# File ~\anaconda3\lib\site-packages\distributed\client.py:2345, in Client.gather(self, futures, errors, direct, asynchronous)
#    2343 else:
#    2344     local_worker = None
# -> 2345 return self.sync(
#    2346     self._gather,
#    2347     futures,
#    2348     errors=errors,
#    2349     direct=direct,
#    2350     local_worker=local_worker,
#    2351     asynchronous=asynchronous,
#    2352 )
#
# File ~\anaconda3\lib\site-packages\distributed\utils.py:349, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     347     return future
#     348 else:
# --> 349     return sync(
#     350         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     351     )
#
# File ~\anaconda3\lib\site-packages\distributed\utils.py:412, in sync(loop, func, callback_timeout, *args, **kwargs)
#     410 else:
#     411     while not e.is_set():
# --> 412         wait(10)
#     414 if error:
#     415     typ, exc, tb = error
#
# File ~\anaconda3\lib\site-packages\distributed\utils.py:401, in sync.<locals>.wait(timeout)
#     399 def wait(timeout):
#     400     try:
# --> 401         return e.wait(timeout)
#     402     except KeyboardInterrupt:
#     403         loop.add_callback(cancel)
#
# File ~\anaconda3\lib\threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~\anaconda3\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
